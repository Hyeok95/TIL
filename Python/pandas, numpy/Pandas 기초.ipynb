# %% [markdown]
# ## 5.1 Pandas란?

# %% [markdown]
# - pandas는 <b>"python data analysis"</b>의 약자입니다.
# > pandas는 정형 데이터 처리에 특화되어 있다.
#
# - pandas 역시 다양한 머신러닝 라이브러리들에 의존성을 가지고 있습니다.
# > scikit-learn, scipy, statsmodel, tensorflow, pytorch, ...
#
#
# - 간단하게 생각하면, **python에서 excel의 기능을 사용**할 수 있게 됩니다.
# > pandas = python + excel // pandas & excel // pandas VS MS Excel
#
# - 하지만, pandas는 numpy array를 베이스로 지원하며 파이썬과 함께 강력한 시너지를 내기 때문에, 엑셀 그 이상의 퍼포먼스를 냅니다.
# > pandas가 Excel에 비해 고성능 데이터처리에 적합하다.

# %% [markdown]
# ![numpy_data_type](../images/pandas/dataframe.png)

# %% [markdown]
# - Pandas 라이브러리에서 기본적으로 데이터를 다루는 단위는 DataFrame입니다. 흔히 알고있는 spreadsheet와 같은 개념입니다.
#
#
# - 이러한 형태의 데이터는 Structured Data 또는 Panel Data 또는 Tabular Data라고 부릅니다.
#
#
# - pandas를 공부한다는 것은 결국 dataframe의 사용법을 익히고 활용하는 방법을 배운다는 것과 같습니다.
#
#
# - pandas를 잘 활용하면 대부분의 structured data를 자유자재로 다룰 수 있게 됩니다.

# %% [markdown]
# ![pandas_files](../images/pandas/pandas_files.png)

# %% [markdown]
# ## 5.2. Pandas의 기본 자료구조(Series, DataFrame)

# %%
# pandas 라이브러리를 불러옵니다. pd를 약칭으로 사용합니다.
import pandas as pd
import numpy as np
print(pd.__version__)
# Out:
# 1.2.4

# %% [markdown]
# - DataFrame은 2차원 테이블이고, 테이블의 한 줄(행/열)을 Series라고 합니다.
#
#
# - Series의 모임이 곧, DataFrame이 됩니다.

# %%
# s는 1, 3, 5, np.nan, 6, 8을 원소로 가지는 pandas.Series
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# - pandas는 date_range라는 함수를 통해, 날짜정보를 쉽게 생성해주는 객체도 제공합니다.

# %%
# 20210101부터 6일간의 날짜 범위를 생성하는 pandas.date_range
dates = pd.date_range('20210101', periods=6)
dates
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
# 6x4 행렬에 -1에서 1 사이의 랜덤한 숫자를 가지는 원소를 가지고, index열은 dates, 나머지 coulmns은 순서대로 A, B, C, D로 하는 DataFrame 생성
df = pd.DataFrame(np.random.randn(6, 4), index = dates, columns = ['A', 'B', 'C', 'D'])
df
# Out:
#                    A         B         C         D
# 2021-01-01  0.171061 -1.751561 -1.006392  1.390900
# 2021-01-02  0.092309  0.673067 -0.715019 -1.024037
# 2021-01-03 -0.603161  0.537562 -0.627837 -0.973696
# 2021-01-04 -0.015068  1.245419 -1.876582  0.872252
# 2021-01-05  1.783304  1.015156 -0.615886  2.042194
# 2021-01-06  0.483636  0.273775  0.205632 -1.273566

# %% [markdown]
# ## 5.3. Dataframe 기초 method

# %%
# dataframe의 맨 위 다섯줄을 보여주는 head()
df.head()
# Out:
#                    A         B         C         D
# 2021-01-01 -0.734055 -0.562238  0.979784  0.672417
# 2021-01-02 -1.250791  1.064162 -0.804566 -0.076608
# 2021-01-03 -0.913730 -0.626797  1.062731  1.839246
# 2021-01-04  0.459121 -0.220419  0.483429 -1.104315
# 2021-01-05 -0.335130 -0.378503 -0.156978  0.405505

# %%
# 3줄
df.head(3) #앞부터
df.tail(3) #뒤부터
# Out:
#                    A         B         C         D
# 2021-01-04  0.459121 -0.220419  0.483429 -1.104315
# 2021-01-05 -0.335130 -0.378503 -0.156978  0.405505
# 2021-01-06 -2.360820  0.295936  0.429938  0.280345

# %%
# dataframe index
df.index
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
# dataframe columns
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# dataframe values
df.values
# Out:
# array([[-0.73405538, -0.5622384 ,  0.979784  ,  0.67241708],
#        [-1.25079113,  1.06416188, -0.80456643, -0.07660761],
#        [-0.91372963, -0.62679696,  1.06273091,  1.83924594],
#        [ 0.45912111, -0.2204192 ,  0.48342866, -1.10431492],
#        [-0.33513043, -0.37850301, -0.15697787,  0.4055048 ],
#        [-2.36081959,  0.29593611,  0.42993769,  0.28034468]])

# %%
# dataframe에 대한 전체적인 요약정보를 보여줍니다. index, columns, null/not-null/dtype/memory usage가 표시됩니다.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6 entries, 2021-01-01 to 2021-01-06
# Freq: D
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       6 non-null      float64
#  1   B       6 non-null      float64
#  2   C       6 non-null      float64
#  3   D       6 non-null      float64
# dtypes: float64(4)
# memory usage: 240.0 bytes

# %%
# dataframe에 대한 전체적인 통계정보를 보여줍니다.
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.855901 -0.071310  0.332389  0.336098
# std    0.942273  0.646582  0.709506  0.961832
# min   -2.360820 -0.626797 -0.804566 -1.104315
# 25%   -1.166526 -0.516305 -0.010249  0.012630
# 50%   -0.823893 -0.299461  0.456683  0.342925
# 75%   -0.434862  0.166847  0.855695  0.605689
# max    0.459121  1.064162  1.062731  1.839246

# %%
# column B를 기준으로 내림차순 정렬
df.sort_values('B',ascending=False).head(3) # column B를 기준으로 값이 큰 top 3
# Out:
#                    A         B         C         D
# 2021-01-02 -1.250791  1.064162 -0.804566 -0.076608
# 2021-01-06 -2.360820  0.295936  0.429938  0.280345
# 2021-01-04  0.459121 -0.220419  0.483429 -1.104315

# %% [markdown]
# ## 5.4. DataFrame Indexing
#
# > Indexing : 데이터에서 어떤 특정 조건을 만족하는 원소를 찾는 방법.
#
# > 전체 DataFrame에서 조건에 만족하는 데이터를 쉽게 찾아서 조작할 때 유용하게 사용할 수 있습니다.

# %%
# pandas dataframe은 column 이름을 이용하여 기본적인 Indexing이 가능합니다.
# column A를 indexing
df ["A"]
# Out:
# 2021-01-01    0.171061
# 2021-01-02    0.092309
# 2021-01-03   -0.603161
# 2021-01-04   -0.015068
# 2021-01-05    1.783304
# 2021-01-06    0.483636
# Freq: D, Name: A, dtype: float64

# %%
# 특정날짜를 통한 Indexing
df.loc['2021-01-01'] #pd.Series
# Out:
# A    0.171061
# B   -1.751561
# C   -1.006392
# D    1.390900
# Name: 2021-01-01 00:00:00, dtype: float64

# %%
# 특정 위치를 통한 indexing
df.iloc[2]
# Out:
# A   -0.603161
# B    0.537562
# C   -0.627837
# D   -0.973696
# Name: 2021-01-03 00:00:00, dtype: float64

# %%
# dataframe에서 slicing을 이용하면 row 단위로 잘려나옵니다.
# 앞에서 3줄을 slicing 합니다.
df[:3]
# Out:
#                    A         B         C         D
# 2021-01-01  0.171061 -1.751561 -1.006392  1.390900
# 2021-01-02  0.092309  0.673067 -0.715019 -1.024037
# 2021-01-03 -0.603161  0.537562 -0.627837 -0.973696

# %%
# df에서 index value를 기준으로 indexing도 가능합니다. (여전히 row 단위)
# 20210102부터 20210104까지 잘라봅니다. # index의 값을 사용하게되면 Index를 이용한 slicing
df['2021-01-02' : '2021-01-04']
# Out:
#                    A         B         C         D
# 2021-01-02  0.092309  0.673067 -0.715019 -1.024037
# 2021-01-03 -0.603161  0.537562 -0.627837 -0.973696
# 2021-01-04 -0.015068  1.245419 -1.876582  0.872252

# %%
df.loc['2021-01-02']
# Out:
# A    0.092309
# B    0.673067
# C   -0.715019
# D   -1.024037
# Name: 2021-01-02 00:00:00, dtype: float64

# %%
# df.loc는 특정값을 기준으로 indexing합니다. (key - value)
# 2021-01-01값을 가지는 row를 가져옵니다.
df.loc[dates[0]]
# Out:
# A    0.171061
# B   -1.751561
# C   -1.006392
# D    1.390900
# Name: 2021-01-01 00:00:00, dtype: float64

# %%
# df.loc에 2차원 indexing도 가능합니다. [:, ["A", "B"]]의 의미는 모든 row에 대해서 columns는 A, B만 가져오라는 의미입니다.
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2021-01-01  0.171061 -1.751561
# 2021-01-02  0.092309  0.673067
# 2021-01-03 -0.603161  0.537562
# 2021-01-04 -0.015068  1.245419
# 2021-01-05  1.783304  1.015156
# 2021-01-06  0.483636  0.273775

# %%
# 이번엔 slicing을 통해 특정 row중에서 columns는 A, B
df.loc['2021-01-03' : '2021-01-05', ['A', 'B']]
# Out:
#                    A         B
# 2021-01-03 -0.603161  0.537562
# 2021-01-04 -0.015068  1.245419
# 2021-01-05  1.783304  1.015156

# %%
# 특정 row를 index값을 통한 indexing
df.loc['2021-01-02', ['A', 'B']] #Series
# Out:
# A    0.092309
# B    0.673067
# Name: 2021-01-02 00:00:00, dtype: float64

# %%
# 2차원 리스트 indexing과 같은 원리가 되었습니다.
df.loc['2021-01-01', 'C'] #특정 row에 특정 column값
# Out:
# -1.0063916508722561

# %%
# df.iloc는 정수를 이용한 indexing과 같습니다.(row 기준) 3은 4번째를 의미합니다.
df.iloc[3]
# Out:
# A   -0.015068
# B    1.245419
# C   -1.876582
# D    0.872252
# Name: 2021-01-04 00:00:00, dtype: float64

# %%
# iloc로 2차원 indexing을 하게되면, row 기준으로 index 3,4를 가져오고 column 기준으로 0, 1을 가져옵니다.
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2021-01-04 -0.015068  1.245419
# 2021-01-05  1.783304  1.015156

# %%
# slicing이 아닌 직접 리스트 형태로 기재하는 indexing
df.iloc[[1, 2, 4], [0, 3]]
# Out:
#                    A         D
# 2021-01-02  0.092309 -1.024037
# 2021-01-03 -0.603161 -0.973696
# 2021-01-05  1.783304  2.042194

# %%
# Q. 2차원 indexing에 뒤에가 : 면 어떤 의미일까요?
df.iloc[1:3, :]
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2021-01-01 -1.751561 -1.006392
# 2021-01-02  0.673067 -0.715019
# 2021-01-03  0.537562 -0.627837
# 2021-01-04  1.245419 -1.876582
# 2021-01-05  1.015156 -0.615886
# 2021-01-06  0.273775  0.205632

# %%
# numpy array의 2차원 indexing과 같다.

# %%
df> 0
# Out:
#                 A      B      C      D
# 2021-01-01   True  False  False   True
# 2021-01-02   True   True  False  False
# 2021-01-03  False   True  False  False
# 2021-01-04  False   True  False   True
# 2021-01-05   True   True  False   True
# 2021-01-06   True   True   True  False

# %%
# pandas는 fancy indexing을 지원합니다. (사실 numpy에서 지원하기 때문에 pandas도 지원합니다.)
# fancy indexing이란 조건문을 통해 indexing을 할 수 있는 방법으로 True와 False를 원소로 하는 리스트를 통해 masking하는 원리로 동작합니다.
# column A에 있는 원소들중에 0보다 큰 데이터를 가져옵니다.
df['A'] > 0
# Out:
# 2021-01-01     True
# 2021-01-02     True
# 2021-01-03    False
# 2021-01-04    False
# 2021-01-05     True
# 2021-01-06     True
# Freq: D, Name: A, dtype: bool

# %%
# fancy indexing
df[df['A'] > 0]
# Out:
#                    A         B         C         D
# 2021-01-01  0.171061 -1.751561 -1.006392  1.390900
# 2021-01-02  0.092309  0.673067 -0.715019 -1.024037
# 2021-01-05  1.783304  1.015156 -0.615886  2.042194
# 2021-01-06  0.483636  0.273775  0.205632 -1.273566

# %%
df[df < 0] = 0
df
# Out:
#                    A         B         C         D
# 2021-01-01  0.171061  0.000000  0.000000  1.390900
# 2021-01-02  0.092309  0.673067  0.000000  0.000000
# 2021-01-03  0.000000  0.537562  0.000000  0.000000
# 2021-01-04  0.000000  1.245419  0.000000  0.872252
# 2021-01-05  1.783304  1.015156  0.000000  2.042194
# 2021-01-06  0.483636  0.273775  0.205632  0.000000

# %%
#df[df > 0]
df[df > 0]
# Out:
#                    A         B         C         D
# 2021-01-01  0.171061       NaN       NaN  1.390900
# 2021-01-02  0.092309  0.673067       NaN       NaN
# 2021-01-03       NaN  0.537562       NaN       NaN
# 2021-01-04       NaN  1.245419       NaN  0.872252
# 2021-01-05  1.783304  1.015156       NaN  2.042194
# 2021-01-06  0.483636  0.273775  0.205632       NaN

# %%
 # dataframe 하나를 복사합니다. 정말 말그대로 복사합니다.
df2 = df.copy()

# %%
# dataframe은 dictionary와 비슷한 방식으로 assignment가 가능합니다.
# df에 ['one', 'one','two','three','four','three'] 리스트를 column의 value로 하는 column E를 추가합니다.
df2['E'] = ('one', 'one', 'two', 'three', 'four', 'three')
df2
# Out:
#                    A         B         C         D      E
# 2021-01-01  0.171061  0.000000  0.000000  1.390900    one
# 2021-01-02  0.092309  0.673067  0.000000  0.000000    one
# 2021-01-03  0.000000  0.537562  0.000000  0.000000    two
# 2021-01-04  0.000000  1.245419  0.000000  0.872252  three
# 2021-01-05  1.783304  1.015156  0.000000  2.042194   four
# 2021-01-06  0.483636  0.273775  0.205632  0.000000  three

# %%
# df.isin은 해당 value들이 들어있는 row에 대해선 True를 가지는 Series를 리턴한다.
df2['E'].isin(['two','four'])
# Out:
# 2021-01-01    False
# 2021-01-02    False
# 2021-01-03     True
# 2021-01-04    False
# 2021-01-05     True
# 2021-01-06    False
# Freq: D, Name: E, dtype: bool

# %%
df[df2['E'].isin(['two','four'])]
# Out:
#                    A         B    C         D
# 2021-01-03  0.000000  0.537562  0.0  0.000000
# 2021-01-05  1.783304  1.015156  0.0  2.042194

# %% [markdown]
# ## 5.5. 외부 데이터 읽고 쓰기

# %%
# data 폴더에 있는 iris.csv를 불러오자.
import pandas as pd
import numpy as np
data = pd.read_csv("data/iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
set(data['Species']) ## 0 , 1, 2
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
# Species column을 숫자로 바꿔보자.
data.loc[data["Species"] == "Iris-setosa","Species"] = 0
data.loc[data["Species"] == "Iris-versicolor","Species"] = 1
data.loc[data["Species"] == "Iris-virginica","Species"] = 2
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm Species
# 0      1            5.1           3.5            1.4           0.2       0
# 1      2            4.9           3.0            1.4           0.2       0
# 2      3            4.7           3.2            1.3           0.2       0
# 3      4            4.6           3.1            1.5           0.2       0
# 4      5            5.0           3.6            1.4           0.2       0
# ..   ...            ...           ...            ...           ...     ...
# 145  146            6.7           3.0            5.2           2.3       2
# 146  147            6.3           2.5            5.0           1.9       2
# 147  148            6.5           3.0            5.2           2.0       2
# 148  149            6.2           3.4            5.4           2.3       2
# 149  150            5.9           3.0            5.1           1.8       2
#
# [150 rows x 6 columns]

# %%
set(data["Species"])
# Out:
# {0, 1, 2}

# %%
# 바꾼 Dataframe을 Iris_edited.csv 로 저장하자.
data.to_csv("data/Iris_edited.csv")

# %%
# 다른 파일도 불러오자.
data2 = pd.read_csv("data/kaggle_survey_2020_responses.csv")
data2
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                    1838                        35-39
# 2                                  289287                        30-34
# 3                                     860                        35-39
# 4                                     507                        30-34
# ...                                   ...                          ...
# 20032                                 126                        18-21
# 20033                                 566                        55-59
# 20034                                 238                        30-34
# 20035                                 625                        22-24
# 20036                                1031                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# 4                                         Man
# ...                                       ...
# 20032                                     Man
# 20033                                   Woman
# 20034                                     Man
# 20035                                     Man
# 20036                                     Man
#
#                                                       Q3  \
# 0              In which country do you currently reside?
# 1                                               Colombia
# 2                               United States of America
# 3                                              Argentina
# 4                               United States of America
# ...                                                  ...
# 20032                                             Turkey
# 20033  United Kingdom of Great Britain and Northern I...
# 20034                                             Brazil
# 20035                                              India
# 20036                                           Pakistan
#
#                                                       Q4  \
# 0      What is the highest level of formal education ...
# 1                                        Doctoral degree
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# ...                                                  ...
# 20032  Some college/university study without earning ...
# 20033                                    Master’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
#                                                       Q5  \
# 0      Select the title most similar to your current ...
# 1                                                Student
# 2                                          Data Engineer
# 3                                      Software Engineer
# 4                                         Data Scientist
# ...                                                  ...
# 20032                                                NaN
# 20033                             Currently not employed
# 20034                                 Research Scientist
# 20035                                  Software Engineer
# 20036                          Machine Learning Engineer
#
#                                                       Q6  \
# 0      For how many years have you been writing code ...
# 1                                             5-10 years
# 2                                             5-10 years
# 3                                            10-20 years
# 4                                             5-10 years
# ...                                                  ...
# 20032                                                NaN
# 20033                                          20+ years
# 20034                                          < 1 years
# 20035                                          3-5 years
# 20036                                          < 1 years
#
#                                                Q7_Part_1  \
# 0      What programming languages do you use on a reg...
# 1                                                 Python
# 2                                                 Python
# 3                                                    NaN
# 4                                                 Python
# ...                                                  ...
# 20032                                                NaN
# 20033                                             Python
# 20034                                             Python
# 20035                                             Python
# 20036                                             Python
#
#                                                Q7_Part_2  \
# 0      What programming languages do you use on a reg...
# 1                                                      R
# 2                                                      R
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                                Q7_Part_3  ...  \
# 0      What programming languages do you use on a reg...  ...
# 1                                                    SQL  ...
# 2                                                    SQL  ...
# 3                                                    NaN  ...
# 4                                                    SQL  ...
# ...                                                  ...  ...
# 20032                                                NaN  ...
# 20033                                                NaN  ...
# 20034                                                NaN  ...
# 20035                                                SQL  ...
# 20036                                                NaN  ...
#
#                                             Q35_B_Part_2  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                  Weights & Biases
# 20036                                  Weights & Biases
#
#                                             Q35_B_Part_3  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_4  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_5  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                           TensorBoard
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                       TensorBoard
# 20036                                                NaN
#
#                                             Q35_B_Part_6  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_7  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_8  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                            Trains
# 20036                                            Trains
#
#                                             Q35_B_Part_9  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                            Q35_B_Part_10  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                   None
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                               None
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                              Q35_B_OTHER
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
# [20037 rows x 355 columns]

# %%
# 박사 학위 소지자들만 골라보자.
phd = data2[data2['Q4'] == "Doctoral degree"]
phd
# Out:
#       Time from Start to Finish (seconds)     Q1                 Q2  \
# 1                                    1838  35-39                Man
# 9                                     762  35-39                Man
# 12                                    742  35-39                Man
# 21                                   3313  22-24              Woman
# 33                                    459  30-34                Man
# ...                                   ...    ...                ...
# 20003                                 917  30-34                Man
# 20005                                 406  30-34                Man
# 20007                                 487  45-49                Man
# 20011                                 375  40-44                Man
# 20020                                 611  25-29  Prefer not to say
#
#                                                       Q3               Q4  \
# 1                                               Colombia  Doctoral degree
# 9                                                Germany  Doctoral degree
# 12                              United States of America  Doctoral degree
# 21                                                 India  Doctoral degree
# 33                                                 Other  Doctoral degree
# ...                                                  ...              ...
# 20003                                           Colombia  Doctoral degree
# 20005                                              Italy  Doctoral degree
# 20007                           United States of America  Doctoral degree
# 20011  United Kingdom of Great Britain and Northern I...  Doctoral degree
# 20020                                            Germany  Doctoral degree
#
#                               Q5           Q6 Q7_Part_1 Q7_Part_2 Q7_Part_3  \
# 1                        Student   5-10 years    Python         R       SQL
# 9                 Data Scientist   5-10 years    Python       NaN       SQL
# 12            Research Scientist    1-2 years       NaN         R       NaN
# 21                  Statistician    3-5 years       NaN         R       SQL
# 33     Machine Learning Engineer  10-20 years    Python       NaN       NaN
# ...                          ...          ...       ...       ...       ...
# 20003          Software Engineer   5-10 years    Python       NaN       SQL
# 20005             Data Scientist  10-20 years    Python       NaN       SQL
# 20007          Software Engineer    20+ years    Python       NaN       NaN
# 20011         Research Scientist   5-10 years    Python         R       NaN
# 20020         Research Scientist  10-20 years    Python       NaN       NaN
#
#        ...        Q35_B_Part_2 Q35_B_Part_3          Q35_B_Part_4  \
# 1      ...                 NaN          NaN                   NaN
# 9      ...                 NaN          NaN                   NaN
# 12     ...                 NaN          NaN                   NaN
# 21     ...   Weights & Biases           NaN                   NaN
# 33     ...                 NaN          NaN                   NaN
# ...    ...                 ...          ...                   ...
# 20003  ...   Weights & Biases     Comet.ml    Sacred + Omniboard
# 20005  ...                 NaN          NaN                   NaN
# 20007  ...                 NaN          NaN                   NaN
# 20011  ...                 NaN          NaN                   NaN
# 20020  ...                 NaN          NaN                   NaN
#
#         Q35_B_Part_5 Q35_B_Part_6 Q35_B_Part_7 Q35_B_Part_8  \
# 1       TensorBoard           NaN          NaN          NaN
# 9                NaN          NaN          NaN          NaN
# 12               NaN          NaN          NaN          NaN
# 21               NaN          NaN          NaN          NaN
# 33               NaN          NaN          NaN          NaN
# ...              ...          ...          ...          ...
# 20003   TensorBoard     Guild.ai     Polyaxon       Trains
# 20005            NaN          NaN          NaN          NaN
# 20007            NaN          NaN          NaN          NaN
# 20011            NaN          NaN          NaN          NaN
# 20020            NaN          NaN          NaN          NaN
#
#                  Q35_B_Part_9 Q35_B_Part_10 Q35_B_OTHER
# 1                         NaN           NaN         NaN
# 9                         NaN           NaN         NaN
# 12                        NaN           NaN         NaN
# 21                        NaN           NaN         NaN
# 33                        NaN           NaN         NaN
# ...                       ...           ...         ...
# 20003   Domino Model Monitor            NaN         NaN
# 20005                     NaN          None         NaN
# 20007                     NaN           NaN         NaN
# 20011                     NaN           NaN         NaN
# 20020                     NaN           NaN         NaN
#
# [2302 rows x 355 columns]

# %%
# 박사 학위 소지자들에 대한 정보만 kaggle_survey_2020_phd.csv로 다시 저장하자.
phd.to_csv("data/kaggle_survey_2020_phd.csv")

# %%
# (OPTIONAL) 박사 학위 소지자이면서, 대한민국 국적을 가진 사람들을 뽑아보자.
data2[data2['Q4'] == "Doctoral degree"]
data2['Q3'] == "South Korea"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 20032    False
# 20033    False
# 20034    False
# 20035    False
# 20036    False
# Name: Q3, Length: 20037, dtype: bool
