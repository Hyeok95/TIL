# %%
import pymysql
from flask import Flask, render_template
# 필요한 모듈들을 import합니다.
import enum
from flask_sqlalchemy import SQLAlchemy
db = SQLAlchemy()

class OrderMethod(enum.Enum):
    card = "card"
    cash = "cash"

# 지시사항 1번을 참고하여 코드를 작성하세요.
class User(db.Model):
    id = db.Column(db.String(10), primary_key= True)
    delivery_address =db.Column(db.String(100), nullable=False)
    order_method = db.Column(db.Enum(OrderMethod), nullable=False)
    
    def __init__(self, id, delivery_address, order_method):
        self.id = id
        self.delivery_address = delivery_address
        self.order_method = order_method

class Store(db.Model):
    id =db.Column(db.String(30), primary_key= True)
    store_address = db.Column(db.String(100), nullable=False)
    contact_number = db.Column(db.String(14), nullable=False)
    
    def __init__(self, id, store_address, contact_number):
        self.id = id
        self.store_address = store_address
        self.contact_number = contact_number

class DeliveryOrder(db.Model):
    id = db.Column(db.Integer, primary_key=True, autoincrement=True)
    user_id = db.Column(db.String(10), nullable=False)
    store_id = db.Column(db.String(30), nullable=False)
    total_price = db.Column(db.Integer, nullable=False)
    delivery_fee =db.Column(db.Integer, nullable=False)
    order_dt = db.Column(db.DateTime, nullable=False)
    order_method = db.Column(db.Enum(OrderMethod), nullable=False)
    delivery_address = db.Column(db.String(100), nullable=False)

    def __init__(self, user_id, store_id, total_price, delivery_fee, order_method, delivery_address):
        self.user_id = user_id
        self.store_id = store_id
        self.total_price = total_price
        self.delivery_fee = delivery_fee
        self.order_method = order_method
        self.delivery_address = delivery_address

app = Flask(__name__)

app.config['SQLALCHEMY_DATABASE_URI'] = "mysql+pymysql://root:devpass@127.0.0.1:3306/elice_flask_board"
app.config['SQLALCHEMY_TRACK_MODIFICATIONS'] = False 

db.init_app(app)


@app.route("/")
def home():
    user_id = "elice"
    order_method = "card"
    delivery_address = "서울특별시 강남구"
    user = User(user_id, delivery_address, order_method)
    db.session.add(user)

    store_id = "엘리스 떡볶이"
    store = Store(store_id, "서울특별시 강남구", "02-1234-5678")
    db.session.add(store)

    # 지시사항 2번을 참고하여 코드를 작성하세요.
    order = DeliveryOrder(user_id, store_id, 13000, 3000, order_method, delivery_address)
    db.session.add(order)
    db.session.commit()

    return "ok"


@app.route("/orders")
def orders():
    # 지시사항 3번을 참고하여 코드를 작성하세요.
    data = DeliveryOrder.query.all()
    
    orders = [
        {
            'user_id':d.user_id,
            'store_id':d.store_id,
            'total_price':d.total_price,
            'delivery_fee':d.delivery_fee,
            'order_method':d.order_method.value,
            'delivery_address':d.delivery_address,
        }
        for d in data
    ]

    return render_template('orders.html', orders=orders)


if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2021-10-01 14:44:52,135] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 3141, in _wrap_pool_connect
#     return fn()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 755, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 211, in raise_
#     raise exception
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 362, in __init__
#     self.__connect(first_connect_check=True)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 211, in raise_
#     raise exception
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\engine\create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 559, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\connections.py", line 353, in __init__
#     self.connect()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\connections.py", line 633, in connect
#     self._request_authentication()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# pymysql.err.OperationalError: (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\chahn\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\chahn\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "<ipython-input-1-9d63171df8db>", line 74, in home
#     db.session.commit()
#   File "<string>", line 2, in commit
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\session.py", line 1423, in commit
#     self._transaction.commit(_to_root=self.future)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\session.py", line 829, in commit
#     self._prepare_impl()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\session.py", line 808, in _prepare_impl
#     self.session.flush()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\session.py", line 3241, in flush
#     self._flush(objects)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\session.py", line 3381, in _flush
#     transaction.rollback(_capture_exception=True)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 211, in raise_
#     raise exception
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\session.py", line 3341, in _flush
#     flush_context.execute()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\unitofwork.py", line 453, in execute
#     rec.execute(self)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\unitofwork.py", line 627, in execute
#     util.preloaded.orm_persistence.save_obj(
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\persistence.py", line 209, in save_obj
#     for (
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\persistence.py", line 370, in _organize_states_for_save
#     for state, dict_, mapper, connection in _connections_for_states(
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\persistence.py", line 1709, in _connections_for_states
#     connection = uowtransaction.transaction.connection(base_mapper)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\session.py", line 626, in connection
#     return self._connection_for_bind(bind, execution_options)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\session.py", line 735, in _connection_for_bind
#     conn = self._parent._connection_for_bind(bind, execution_options)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\orm\session.py", line 747, in _connection_for_bind
#     conn = bind.connect()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 3095, in connect
#     return self._connection_cls(self, close_with_result=close_with_result)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 91, in __init__
#     else engine.raw_connection()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 3174, in raw_connection
#     return self._wrap_pool_connect(self.pool.connect, _connection)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 3144, in _wrap_pool_connect
#     Connection._handle_dbapi_exception_noconnection(
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 2003, in _handle_dbapi_exception_noconnection
#     util.raise_(
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 211, in raise_
#     raise exception
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\engine\base.py", line 3141, in _wrap_pool_connect
#     return fn()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 301, in connect
#     return _ConnectionFairy._checkout(self)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 755, in _checkout
#     fairy = _ConnectionRecord.checkout(pool)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 419, in checkout
#     rec = pool._do_get()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py", line 145, in _do_get
#     self._dec_overflow()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 211, in raise_
#     raise exception
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\impl.py", line 142, in _do_get
#     return self._create_connection()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 247, in _create_connection
#     return _ConnectionRecord(self)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 362, in __init__
#     self.__connect(first_connect_check=True)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 605, in __connect
#     pool.logger.debug("Error on connect(): %s", e)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\util\langhelpers.py", line 70, in __exit__
#     compat.raise_(
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\util\compat.py", line 211, in raise_
#     raise exception
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\pool\base.py", line 599, in __connect
#     connection = pool._invoke_creator(self)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\engine\create.py", line 578, in connect
#     return dialect.connect(*cargs, **cparams)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\sqlalchemy\engine\default.py", line 559, in connect
#     return self.dbapi.connect(*cargs, **cparams)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\connections.py", line 353, in __init__
#     self.connect()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\connections.py", line 633, in connect
#     self._request_authentication()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\connections.py", line 907, in _request_authentication
#     auth_packet = self._read_packet()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\connections.py", line 725, in _read_packet
#     packet.raise_for_error()
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\protocol.py", line 221, in raise_for_error
#     err.raise_mysql_exception(self._data)
#   File "C:\Users\chahn\anaconda3\lib\site-packages\pymysql\err.py", line 143, in raise_mysql_exception
#     raise errorclass(errno, errval)
# sqlalchemy.exc.OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'root'@'localhost' (using password: YES)")
# (Background on this error at: http://sqlalche.me/e/14/e3q8)
# 127.0.0.1 - - [01/Oct/2021 14:44:52] "GET / HTTP/1.1" 500 -
